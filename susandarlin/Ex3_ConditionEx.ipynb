# %% [markdown]
# <a href="https://colab.research.google.com/github/susandarlin/MMDT_T-PY101_Batch03/blob/main/susandarlin/Ex3_ConditionEx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program that asks the user to enter a length in centimeters. If the user enters a negative length, the program should tell the user that the entry is invalid. Otherwise, the program should convert the length to inches and print out the result. There are 2.54 centimeters in an inch.

# %%
centimeter = input("Enter a length in centimeters: ")
i_centimeter = int(centimeter)
if(i_centimeter < 0):
  print("Negative length")
else:
  inch = i_centimeter * 2.54
  print(inch)
# Out:
# Enter a length in centimeters: 1
# 2.54

# %% [markdown]
# Ask the user to enter a temperature in Celsius. The program should print a message based on the temperature:
#
# *   If the temperature is less than -273.15, print that the temperature is invalid because it is below absolute zero.
# *   If it is exactly -273.15, print that the temperature is absolute 0.
# *   If the temperature is between -273.15 and 0, print that the temperature is below freezing.
# *   If it is 0, print that the temperature is at the freezing point.
# *   If it is between 0 and 100, print that the temperature is in the normal range.
# *   If it is 100, print that the temperature is at the boiling point.
# *   If it is above 100, print that the temperature is above the boiling point.

# %%
celsius = input("Enter a length in Celsius: ")
f_celsius = float(celsius)

if(f_celsius < -273.15):
  print("Temperature is invalid.")
elif(f_celsius == -273.15):
  print("Temperature is absolute 0.")
elif(f_celsius > -273.15 and f_celsius < 0):
  print("Temperature is below freezing.")
elif(f_celsius == 0):
  print("Temperature is at the freezing point.")
elif(f_celsius > 0 and f_celsius < 100):
  print("Temperature is in the normal range.")
elif(f_celsius == 100):
  print("Temperature is at the boiling point.")
elif(f_celsius > 100):
  print("Temperature is above the boiling point.")
# Out:
# Enter a length in Celsius: 101
# Temperature is above the boiling point.

# %% [markdown]
# Write a program that asks the user how many credits they have taken. If they have taken 23 or less, print that the student is a freshman. If they have taken between 24 and 53, print that they are a sophomore. The range for juniors is 54 to 83, and for seniors it is 84 and over.

# %%
credit = input("Enter credits they have taken: ")
f_credit = float(credit)

if(f_credit <= 23):
  print("The student is a freshman.")
elif(f_credit >= 24 and f_credit <= 53):
  print("The student is a sophomore.")
elif(f_credit >= 54 and f_credit <= 83):
  print("The student is a juniors.")
elif(f_credit >= 84):
  print("The student is a seniors.")
# Out:
# Enter credits they have taken: 90
# The student is a seniors.
